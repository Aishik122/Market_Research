# %%
import numpy as np
import pandas as pd

# %%
kolkata=pd.read_csv(r'C:\Users\Aishik\Downloads\Kolkata.csv')
Bidhannagar=pd.read_csv(r'C:\Users\Aishik\Downloads\Bidhannagar.csv')
Sealdah=pd.read_csv(r'C:\Users\Aishik\Downloads\Sealdah.csv')
Sector5=pd.read_csv(r'C:\Users\Aishik\Downloads\Sector5.csv')
Howrah=pd.read_csv(r'C:\Users\Aishik\Downloads\Howrah.csv')
Siliguri=pd.read_csv(r'C:\Users\Aishik\Downloads\Siliguri.csv')
Asansol=pd.read_csv(r'C:\Users\Aishik\Downloads\Asansol.csv')
Darjeeling=pd.read_csv(r'C:\Users\Aishik\Downloads\Darjeeling.csv')
Durgapur=pd.read_csv(r'C:\Users\Aishik\Downloads\Durgapur.csv')
Haldia=pd.read_csv(r'C:\Users\Aishik\Downloads\Haldia.csv')
Hoogly=pd.read_csv(r'C:\Users\Aishik\Downloads\Hoogly.csv')
kharagpur=pd.read_csv(r'C:\Users\Aishik\Downloads\kharagpur.csv')
Ranigang=pd.read_csv(r'C:\Users\Aishik\Downloads\Ranigang.csv')

# %%
kolkata.sample(5)
# Out:
#                              qBF1Pd                                W4Efsd  \
# 93           K Plastics & Chemicals                          Manufacturer
# 89  Maschinen Fabrik India pvt. Ltd  Material handling equipment supplier
# 67               New Horizon Groups                              Supplier
# 31  Southern Cooling Towers Pvt Ltd         Industrial equipment supplier
# 28                  Synotrix Global                                     ·
#
#                                            W4Efsd 2  MW4etd UY7F9  \
# 93                                                ·     NaN   NaN
# 89                                                ·     NaN   NaN
# 67                                              NaN     3.7    -3
# 31                                                ·     3.4   -10
# 28  Merlin Matrix, Block DN-10, Salt Lake, Sector V     2.9   -10
#
#             UsdlK
# 93  033 4064 2018
# 89  033 2474 9975
# 67            NaN
# 31  033 2232 1777
# 28  033 6607 9538

# %%
kolkata.columns=['company_name','company_type','Location','review','no_user_review','contact']

# %%
Bidhannagar.head()
# Out:
#                                  qBF1Pd            W4Efsd  \
# 0                       Synotrix Global  Software company
# 1     OV International Services Pvt Ltd  Software company
# 2                           Buildfusion  Software company
# 3                      IBM BCS Building  Software company
# 4  LabVantage Solutions Private Limited  Software company
#
#                                             W4Efsd 3  MW4etd UY7F9  \
# 0    Merlin Matrix, Block DN-10, Salt Lake, Sector V     2.9   -10
# 1                                 8th Floor, GN 34/1     3.4    -5
# 2                        CG - 79, Salt Lake City, 79     4.7   -10
# 3                         HCCM+RQH, Street Number 20     4.6  -770
# 4  Salt Lake Electronics Complex, Bengal Intellig...     4.8   -63
#
#            UsdlK
# 0  033 6607 9538
# 1   090513 40075
# 2  033 2358 0960
# 3            NaN
# 4  033 3982 4200

# %%
Bidhannagar.columns =['company_name','company_type','Location','review','no_user_review','contact']

# %%
Sealdah.head()
# Out:
#                           qBF1Pd                                       W4Efsd  \
# 0  CRYSTAL INTERNATIONAL COMPANY  Real Estate Builders & Construction Company
# 1                  Mnc Companies                                          NaN
# 2                    Birla Sugar                             Corporate office
# 3                  Wipro Limited                             Software company
# 4                        Sealdah                                   Raja Bazar
#
#                                             W4Efsd 3  MW4etd   UY7F9  contact
# 0  ROOM NO. 203, ANNAPURNA BUILDING, Lord Sinha Road     5.0      -5      NaN
# 1                             2, Dr M.L.K. Sarani Rd     NaN     NaN      NaN
# 2  9/1, R.N. Mukherjee Road, Birla Building, 5th ...     4.1      -7      NaN
# 3                         1, 7, 8 & 9, Street No. 13     4.4  -4,085      NaN
# 4                                                NaN     NaN     NaN      NaN

# %%
Sealdah.columns = ['company_name','company_type','Location','review','no_user_review','contact']

# %%
Sector5.head()
# Out:
#                               qBF1Pd            W4Efsd  \
# 0                    Synotrix Global  Software company
# 1  OV International Services Pvt Ltd  Software company
# 2                   IBM BCS Building  Software company
# 3            Ontrack Systems Limited  Software company
# 4             RS Software India Ltd.  Software company
#
#                                           W4Efsd 3  MW4etd   UY7F9  \
# 0  Merlin Matrix, Block DN-10, Salt Lake, Sector V     2.9     -10
# 1                               8th Floor, GN 34/1     3.4      -5
# 2                       HCCM+RQH, Street Number 20     4.6    -770
# 3                 Block-EPY18, Sector-5, Salt Lake     4.0      -1
# 4                     11th Floor, Adventz Infinity     4.2  -2,689
#
#            UsdlK
# 0  033 6607 9538
# 1   090513 40075
# 2            NaN
# 3            NaN
# 4  033 6601 8899

# %%
Sector5.columns = ['company_name','company_type','Location','review','no_user_review','contact']

# %%
Howrah.head()
# Out:
#                                               qBF1Pd                 W4Efsd  \
# 0                      Nirmita Manufacturing Company           Manufacturer
# 1                                  Apogee Industries           Manufacturer
# 2        Howrah Business Corporation Private Limited       Corporate office
# 3  Elevator companies in Kolkata, Elevator compan...  Elevator Manufacturer
# 4             Jaidka Power Systems Pvt. Ltd. Factory           Manufacturer
#
#                                             W4Efsd 3  MW4etd  UY7F9  \
# 0                      6, Gopal Chandra Mukherjee Ln     NaN    NaN
# 1                                 77, 20, Benaras Rd     4.9   -9.0
# 2                              61, Chintamani Dey Rd     NaN    NaN
# 3                           39, P.K. Roychowdhury Ln     NaN    NaN
# 4  Plot No. 3593 Saraswati Industrial Complex,Muk...     4.2   -5.0
#
#           UsdlK
# 0           NaN
# 1  096743 10511
# 2           NaN
# 3  091983 01985
# ...

# %%
Howrah.columns =['company_name','company_type','Location','review','no_user_review','contact']

# %%
Siliguri.head()
# Out:
#                                               qBF1Pd  \
# 0                      Fixfin Technologies Pvt. Ltd.
# 1                                              Kamac
# 2  Hindmake Industries and infrastructures Commod...
# 3                      Groveus Informatics PVT. LTD.
# 4  Dreamegis Technologies Pvt. Ltd. (Siliguri Bra...
#
#                                         W4Efsd  \
# 0                             Software company
# 1  Real Estate Builders & Construction Company
# 2                  Business networking company
# 3                             Software company
# 4                             Software company
#
#                                             W4Efsd 3  MW4etd  UY7F9  \
# 0                                      Webel IT Park     4.9  -32.0
# 1  Ramkrishna Samity Building, Panitanki More, 40...     4.8  -16.0
# 2                                      Champasari Rd     1.0   -1.0
# 3  1st Floor, Dhup company more, Pradhan Nagar, n...     4.7  -63.0
# ...

# %%
Siliguri.columns =['company_name','company_type','Location','review','no_user_review','contact']

# %%
Asansol.head()
# Out:
#                                               qBF1Pd  \
# 0  PageLinko Technologies Private Limited | Web &...
# 1                             Terminaux Techsolution
# 2                                   ArkiTech Asansol
# 3  Steel Authority Of India Limited, IISCO Steel ...
# 4  Dhanvarsha Residency Asansol-Best Real Estate ...
#
#                                         W4Efsd  \
# 0                             Software company
# 1                             Software company
# 2                             Software company
# 3                        Iron & Steel Industry
# 4  Real Estate Builders & Construction Company
#
#                                             W4Efsd 3  MW4etd UY7F9  \
# 0  Module No. 18, 1st Floor, WEBEL IT Park, Kalya...     2.3   -16
# 1                                      Webel It park     1.8    -5
# 2             MWVX+7WH, Near Inn Asansol, Burnpur Rd     4.0    -1
# 3  Burnpur Station Road, Burnpur, District - Bard...     4.2  -248
# ...

# %%
Asansol.columns =['company_name','company_type','Location','review','no_user_review','contact']

# %%
Darjeeling.head()
# Out:
#                                               qBF1Pd            W4Efsd  \
# 0  Avirma Group - Website Development - Software ...  Software company
# 1            Himalayan Manpower Solutions Darjeeling        Consultant
# 2                         Darjeeling Welfare Society  Corporate office
# 3  Federation of Societies for Environmental Prot...  Corporate office
# 4                            Happy Valley Tea Estate            Garden
#
#                                      W4Efsd 3  MW4etd   UY7F9          UsdlK
# 0                                Mount Valley     4.8     -13   089673 05470
# 1  3RD FLOOR, LOACH NAGAR HOTEL MORNING GLORY     3.5     -17   095476 65290
# 2         The Mall, 4, Franklyn Prestage Road     NaN     NaN   089182 02014
# 3                                    27Q7+HP5     5.0      -1  0354 225 8180
# 4      3725+HC5, Lebong Cart Rd, Chauk Bazaar     4.4  -2,227   080177 00700

# %%
Darjeeling.columns = ['company_name','company_type','Location','review','no_user_review','contact']

# %%
Durgapur.head()
# Out:
#                                               qBF1Pd                W4Efsd  \
# 0                        Energia Systems Private Ltd    Automation company
# 1              Groveus Informatics Pvt Ltd, Durgapur      Software company
# 2          Titan Engineering Company Private Limited  Fabrication Engineer
# 3  CONCEPTION TECHNOLOGY : Custom Software, Websi...      Software company
# 4                              FULSY PRIVATE LIMITED      Software company
#
#                              W4Efsd 3  MW4etd  UY7F9          UsdlK
# 0               RC-102 Gitanjali Park     NaN    NaN  033 2337 5717
# 1                 39, Abanindra Bithi     4.9  -36.0   090648 49054
# 2     G85G+323, Sanjib, Nazrul Sarani     3.8  -13.0  0343 255 6160
# 3                   MS-28/29, Urvashi     4.6  -37.0   096141 01653
# 4  Ground Floor, 37, Bagha Jatin Path     2.5   -2.0   081012 44343

# %%
Durgapur.columns = ['company_name','company_type','Location','review','no_user_review','contact']

# %%
Haldia.head()
# Out:
#                                     qBF1Pd                         W4Efsd  \
# 0  South Gate # Haldia Pertochemicals Ltd.          Chemical Manufacturer
# 1       Petro Carbon & Chemicals Pvt. Ltd.          Chemical Manufacturer
# 2        RUC Industrial Solutions Pvt Ltd.  Industrial equipment supplier
# 3                                      HPL                 Chemical plant
# 4            Haldia Petrochemicals Limited                 Chemical plant
#
#                               W4Efsd 3  MW4etd  UY7F9          UsdlK
# 0               3453+MQX, Unnamed Road     5.0   -2.0            NaN
# 1  3457+MM7, P.O. Oil Refinery, Dist.:     3.4   -8.0  03224 252 553
# 2        Durgachak Stadium, 29, Market     3.7   -3.0  03224 272 058
# 3                             3485+89X     4.4  -22.0            NaN
# 4                             3487+MQ5     4.3 -133.0            NaN

# %%
Haldia.columns= ['company_name','company_type','Location','review','no_user_review','contact']

# %%
Hoogly.head()
# Out:
#                               qBF1Pd                 W4Efsd  \
# 0      Shivshakti Agro India Limited           Manufacturer
# 1                  Rakshit Chemicals  Chemical Manufacturer
# 2                           EKSTAC33         Music producer
# 3  The Hooghly Mills Company Limited              Jute Mill
# 4      Hooghly Mills Company Limited       Corporate office
#
#                                             W4Efsd 3  MW4etd UY7F9  contact
# 0                      Dankuni Coal Complex Township     3.5    -6      NaN
# 1  V998+3C8, Kalupukur Main Road, Near Chandannag...     NaN   NaN      NaN
# 2          304, Ghutia Bazar, Shibtala Road, Hooghly     5.0    -2      NaN
# 3          Shop No. 9, Gate No. 1, Garden Reach Road     3.4   -11      NaN
# 4                           3rd Floor, 10, Clive Row     3.0    -1      NaN

# %%
Hoogly.columns= ['company_name','company_type','Location','review','no_user_review','contact']

# %%
kharagpur.head()
# Out:
#                                               qBF1Pd  \
# 0                            Nazis Groups of company
# 1                                        HCM_Service
# 2                                     GLACIER PHARMA
# 3                                         SSGS Group
# 4  Sagar Business private limited. Fabrication Plant
#
#                                         W4Efsd  \
# 0                             Corporate office
# 1                    Computer Hardware Company
# 2                       Pharmaceutical company
# 3  Real Estate Builders & Construction Company
# 4                             Steel fabricator
#
#                                             W4Efsd 3  MW4etd UY7F9  \
# 0                                   984P+HRF, O T Rd     NaN   NaN
# 1                           no. 557, Holding, 324/18     NaN   NaN
# 2                                  Municipality road     3.4    -5
# 3  INDA, Kamala Cabin Civil Defense (Suchana 1, K...     4.3   -17
# ...

# %%
kharagpur.columns=['company_name','company_type','Location','review','no_user_review','contact']

# %%
Ranigang.head()
# Out:
#                                 qBF1Pd            W4Efsd  \
# 0             GEOYN SERVICES PVT. LTD.  Software company
# 1    Maheshwari Mining Private Limited    Mining company
# 2  Abhishek trading co palm oil godown      Manufacturer
# 3                  Maheshwari workshop  Home goods store
# 4                          West Bengal        Dairy farm
#
#                                             W4Efsd 3  MW4etd  UY7F9  \
# 0  2nd Floor, Eye hospital More, Tantia complex, ...     NaN    NaN
# 1                                       21, CLM Lane     4.4  -89.0
# 2                                Bengal shristi, NH2     5.0   -6.0
# 3                                      J4Q8+HJP, NH2     4.0   -4.0
# 4                 3 no, nimcha colleyri, Devi asthan     NaN    NaN
#
#            UsdlK
# 0   081018 80886
# 1  0341 244 5446
# 2            NaN
# 3            NaN
# 4            NaN

# %%
Ranigang.columns=['company_name','company_type','Location','review','no_user_review','contact']

# %%
final_df = pd.concat([kolkata,
Bidhannagar,
Sealdah,
Sector5,
Howrah,
Siliguri,
Asansol,
Darjeeling,
Durgapur,
Haldia,
Hoogly,
kharagpur,
Ranigang,], axis=0)

# %%
final_df.drop(columns=['contact'],inplace=True)

# %%
final_df
# Out:
#                                      company_name       company_type  \
# 0                                   Mnc Companies                  ·
# 1                                     Buildfusion                  ·
# 2   Unisys Softwares & Holding Industries Limited   Software company
# 3                          Mnc Software Companies                  ·
# 4             Brabender Technologie GmbH & Co. KG       Manufacturer
# ..                                            ...                ...
# 3                             Maheshwari workshop   Home goods store
# 4                                     West Bengal         Dairy farm
# 5              Mining and Engineering Corporation     Tractor dealer
# 6                             MAKTECH CORPORATION         Contractor
# 7                               SPL LITTI AND TEA  Food manufacturer
#
#                                             Location  review no_user_review
# ...

# %%
final_df.to_csv(r'D:\Market_research\MNC.csv',index=False)
