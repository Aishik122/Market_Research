# %%
import pandas as pd

# %%
Kolkata=pd.read_csv(r'D:\mar_res_data\StartUps\StartUps_kolkata.csv')
Durgapur=pd.read_csv(r'D:\mar_res_data\StartUps\startUps_durgapur.csv')
Siliguri=pd.read_csv(r'D:\mar_res_data\StartUps\Siliguri.csv')
Raniganj=pd.read_csv(r'D:\mar_res_data\StartUps\Raniganj.csv')
Khadakpur=pd.read_csv(r'D:\mar_res_data\StartUps\Kharagpur.csv')
Howrah=pd.read_csv(r'D:\mar_res_data\StartUps\Howrah.csv')
Hoogly=pd.read_csv(r'D:\mar_res_data\StartUps\Hoogly.csv')
Haldia=pd.read_csv(r'D:\mar_res_data\StartUps\Haldia.csv')
Darjeeling=pd.read_csv(r'D:\mar_res_data\StartUps\Darjeeling.csv')
Asansol=pd.read_csv(r'D:\mar_res_data\StartUps\Asansol.csv')

# %%
df=pd.concat([Kolkata,
Durgapur,
Siliguri,
Raniganj,
Khadakpur,
Howrah,
Hoogly,
Haldia,
Darjeeling,
Asansol],axis=0)

# %%
df.drop(columns=['Contact'],inplace=True)

# %%
df.sample(50)
# Out:
#                                           Company_name  Rating  \
# 1                                 Startup Biz Solution     NaN
# 6                             3SA WEBX PRIVATE LIMITED     5.0
# 18                          SMFG India Credit Co. Ltd.     3.0
# 112                                     Godrej Genesis     3.7
# 2                                 Nanda Millar Company     4.5
# 48                            Hindustan Cables Limited     4.0
# 7                                    Pfizer India Ltd.     5.0
# 35                               Arora Group Sandmines     4.3
# 5                                   CodeLane Solutions     NaN
# 13                           Xplorbuzz Private Limited     5.0
# 0                                Haldia Tech Solutions     5.0
# 9                                        KMC & COMPANY     5.0
# 11                                        Startuptalky     3.7
# 48                               Reliance SMART Bazaar     4.0
# ...

# %%
df.shape
# Out:
# (304, 7)

# %%
df.drop_duplicates(inplace=True)

# %%
df.to_csv(r'D:\Market_research\StartUp.csv',index=False)
