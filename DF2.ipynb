# %%
import numpy as np
import pandas as pd

# %%
kolkata=pd.read_csv(r'C:\Users\Aishik\Downloads\Kolkata.csv')
Bidhannagar=pd.read_csv(r'C:\Users\Aishik\Downloads\Bidhannagar.csv')
Sealdah=pd.read_csv(r'C:\Users\Aishik\Downloads\Sealdah.csv')
Sector5=pd.read_csv(r'C:\Users\Aishik\Downloads\Sector5.csv')
Howrah=pd.read_csv(r'C:\Users\Aishik\Downloads\Howrah.csv')
Siliguri=pd.read_csv(r'C:\Users\Aishik\Downloads\Siliguri.csv')
Asansol=pd.read_csv(r'C:\Users\Aishik\Downloads\Asansol.csv')
Darjeeling=pd.read_csv(r'C:\Users\Aishik\Downloads\Darjeeling.csv')
Durgapur=pd.read_csv(r'C:\Users\Aishik\Downloads\Durgapur.csv')
Haldia=pd.read_csv(r'C:\Users\Aishik\Downloads\Haldia.csv')
Hoogly=pd.read_csv(r'C:\Users\Aishik\Downloads\Hoogly.csv')
kharagpur=pd.read_csv(r'C:\Users\Aishik\Downloads\kharagpur.csv')
Ranigang=pd.read_csv(r'C:\Users\Aishik\Downloads\Ranigang.csv')

# %%
kolkata.sample(5)
# Out:
#                             company_name  \
# 27            Tata International Limited
# 22         Web Spiders (India) Pvt. Ltd.
# 82            Sikaria Group Of Companies
# 16  LabVantage Solutions Private Limited
# 85       Reliance Infrastructure Limited
#
#                                    company_type            Location  review  \
# 27                                 Manufacturer                   ·     NaN
# 22                             Software company                   ·     3.5
# 82                                            ·  4D, Chaitan Sen Ln     NaN
# 16                             Software company                   ·     4.8
# 85  Real Estate Builders & Construction Company                   ·     4.1
#
#    no_user_review        contact
# 27            NaN            NaN
# 22            -21  033 2474 3582
# 82            NaN            NaN
# 16            -63  033 3982 4200
# 85            -15            NaN

# %%
kolkata.columns=['company_name','company_type','Location','review','no_user_review','contact']

# %%
Bidhannagar.head()
# Out:
#                            company_name      company_type  \
# 0                       Synotrix Global  Software company
# 1     OV International Services Pvt Ltd  Software company
# 2                           Buildfusion  Software company
# 3                      IBM BCS Building  Software company
# 4  LabVantage Solutions Private Limited  Software company
#
#                                             Location  review no_user_review  \
# 0    Merlin Matrix, Block DN-10, Salt Lake, Sector V     2.9            -10
# 1                                 8th Floor, GN 34/1     3.4             -5
# 2                        CG - 79, Salt Lake City, 79     4.7            -10
# 3                         HCCM+RQH, Street Number 20     4.6           -770
# 4  Salt Lake Electronics Complex, Bengal Intellig...     4.8            -63
#
#          contact
# 0  033 6607 9538
# 1   090513 40075
# 2  033 2358 0960
# 3            NaN
# 4  033 3982 4200

# %%
Bidhannagar.columns =['company_name','company_type','Location','review','no_user_review','contact']

# %%
Sealdah.head()
# Out:
#                     company_name                                 company_type  \
# 0  CRYSTAL INTERNATIONAL COMPANY  Real Estate Builders & Construction Company
# 1                  Mnc Companies                                          NaN
# 2                    Birla Sugar                             Corporate office
# 3                  Wipro Limited                             Software company
# 4                        Sealdah                                   Raja Bazar
#
#                                             Location  review no_user_review  \
# 0  ROOM NO. 203, ANNAPURNA BUILDING, Lord Sinha Road     5.0             -5
# 1                             2, Dr M.L.K. Sarani Rd     NaN            NaN
# 2  9/1, R.N. Mukherjee Road, Birla Building, 5th ...     4.1             -7
# 3                         1, 7, 8 & 9, Street No. 13     4.4         -4,085
# 4                                                NaN     NaN            NaN
#
#    contact
# 0      NaN
# 1      NaN
# 2      NaN
# 3      NaN
# 4      NaN

# %%
Sealdah.columns = ['company_name','company_type','Location','review','no_user_review','contact']

# %%
Sector5.head()
# Out:
#                         company_name  review no_user_review      company_type  \
# 0                    Synotrix Global     2.9            -10  Software company
# 1  OV International Services Pvt Ltd     3.4             -5  Software company
# 2                   IBM BCS Building     4.6           -770  Software company
# 3            Ontrack Systems Limited     4.0             -1  Software company
# 4             RS Software India Ltd.     4.2         -2,689  Software company
#
#                                           location        contact  \
# 0  Merlin Matrix, Block DN-10, Salt Lake, Sector V  033 6607 9538
# 1                               8th Floor, GN 34/1   090513 40075
# 2                       HCCM+RQH, Street Number 20            NaN
# 3                 Block-EPY18, Sector-5, Salt Lake            NaN
# 4                     11th Floor, Adventz Infinity  033 6601 8899
#
#                                    website
# 0                                      NaN
# 1  http://www.ovinternationalservices.com/
# 2               https://www.ibm.com/in-en/
# 3                                      NaN
# 4               http://www.rssoftware.com/

# %%
Sector5.columns = ['company_name','company_type','Location','review','no_user_review','contact']

# %%
Howrah.head()
# Out:
#                                         company_name           company_type  \
# 0                      Nirmita Manufacturing Company           Manufacturer
# 1                                  Apogee Industries           Manufacturer
# 2        Howrah Business Corporation Private Limited       Corporate office
# 3  Elevator companies in Kolkata, Elevator compan...  Elevator Manufacturer
# 4             Jaidka Power Systems Pvt. Ltd. Factory           Manufacturer
#
#                                             location  review  no_user_review  \
# 0                      6, Gopal Chandra Mukherjee Ln     NaN             NaN
# 1                                 77, 20, Benaras Rd     4.9            -9.0
# 2                              61, Chintamani Dey Rd     NaN             NaN
# 3                           39, P.K. Roychowdhury Ln     NaN             NaN
# 4  Plot No. 3593 Saraswati Industrial Complex,Muk...     4.2            -5.0
#
#         contact                          website open_close
# 0           NaN                              NaN        NaN
# 1  096743 10511  http://www.apogeeindustries.in/        NaN
# 2           NaN                              NaN        NaN
# 3  091983 01985          https://msaelevator.in/        NaN
# 4           NaN            http://www.jaidka.in/        NaN

# %%
Howrah.columns =['company_name','company_type','Location','review','no_user_review','contact']

# %%
Siliguri.head()
# Out:
#                                         company_name  review  no_user_review  \
# 0                      Fixfin Technologies Pvt. Ltd.     4.9           -32.0
# 1                                              Kamac     4.8           -16.0
# 2  Hindmake Industries and infrastructures Commod...     1.0            -1.0
# 3                      Groveus Informatics PVT. LTD.     4.7           -63.0
# 4  Dreamegis Technologies Pvt. Ltd. (Siliguri Bra...     5.0            -5.0
#
#                                   company_type  \
# 0                             Software company
# 1  Real Estate Builders & Construction Company
# 2                  Business networking company
# 3                             Software company
# 4                             Software company
#
#                                             location        contact  \
# 0                                      Webel IT Park   098369 79999
# 1  Ramkrishna Samity Building, Panitanki More, 40...  0353 264 1153
# 2                                      Champasari Rd   099333 44333
# 3  1st Floor, Dhup company more, Pradhan Nagar, n...   098325 11333
# 4  Ward 16, Hakimpara, Beside Madhav Bhavan, Near...            NaN
#
#                                website
# 0  https://www.fixfintechnologies.com/
# 1                     http://kamac.in/
# 2                                  NaN
# 3             https://www.groveus.com/
# 4                                  NaN

# %%
Siliguri.columns =['company_name','company_type','Location','review','no_user_review','contact']

# %%
Asansol.head()
# Out:
#                                         company_name  review no_user_review  \
# 0  PageLinko Technologies Private Limited | Web &...     2.3            -16
# 1                             Terminaux Techsolution     1.8             -5
# 2                                   ArkiTech Asansol     4.0             -1
# 3  Steel Authority Of India Limited, IISCO Steel ...     4.2           -248
# 4  Dhanvarsha Residency Asansol-Best Real Estate ...     5.0            -14
#
#                                   company_type  \
# 0                             Software company
# 1                             Software company
# 2                             Software company
# 3                        Iron & Steel Industry
# 4  Real Estate Builders & Construction Company
#
#                                             location  \
# 0  Module No. 18, 1st Floor, WEBEL IT Park, Kalya...
# 1                                      Webel It park
# 2             MWVX+7WH, Near Inn Asansol, Burnpur Rd
# 3  Burnpur Station Road, Burnpur, District - Bard...
# 4                                             Majira
#
#                                              website        contact
# 0                                                NaN            NaN
# 1                  http://terminauxtechsolution.com/            NaN
# 2                                                NaN            NaN
# 3  https://sail.co.in/en/plants/about-iisco-steel...  0341 224 0441
# 4                                                NaN            NaN

# %%
Asansol.columns =['company_name','company_type','Location','review','no_user_review','contact']

# %%
Darjeeling.head()
# Out:
#                                         company_name  review no_user_review  \
# 0  Avirma Group - Website Development - Software ...     4.8            -13
# 1            Himalayan Manpower Solutions Darjeeling     3.5            -17
# 2                         Darjeeling Welfare Society     NaN            NaN
# 3  Federation of Societies for Environmental Prot...     5.0             -1
# 4                            Happy Valley Tea Estate     4.4         -2,227
#
#        company_type                                    location  \
# 0  Software company                                Mount Valley
# 1        Consultant  3RD FLOOR, LOACH NAGAR HOTEL MORNING GLORY
# 2  Corporate office         The Mall, 4, Franklyn Prestage Road
# 3  Corporate office                                    27Q7+HP5
# 4            Garden      3725+HC5, Lebong Cart Rd, Chauk Bazaar
#
#          contact                                            website
# 0   089673 05470                                                NaN
# 1   095476 65290  https://himalayanmanpower-solutions.business.s...
# 2   089182 02014               http://darjeelingwelfaresociety.com/
# 3  0354 225 8180                       https://fosepdarjeeling.org/
# 4   080177 00700                                                NaN

# %%
Darjeeling.columns = ['company_name','company_type','Location','review','no_user_review','contact']

# %%
Durgapur.head()
# Out:
#                                         company_name          company_type  \
# 0                        Energia Systems Private Ltd    Automation company
# 1              Groveus Informatics Pvt Ltd, Durgapur      Software company
# 2          Titan Engineering Company Private Limited  Fabrication Engineer
# 3  CONCEPTION TECHNOLOGY : Custom Software, Websi...      Software company
# 4                              FULSY PRIVATE LIMITED      Software company
#
#                              location        contact  \
# 0               RC-102 Gitanjali Park  033 2337 5717
# 1                 39, Abanindra Bithi   090648 49054
# 2     G85G+323, Sanjib, Nazrul Sarani  0343 255 6160
# 3                   MS-28/29, Urvashi   096141 01653
# 4  Ground Floor, 37, Bagha Jatin Path   081012 44343
#
#                                 website  review  no_user_review
# 0             http://energiasystems.in/     NaN             NaN
# 1              https://www.groveus.com/     4.9           -36.0
# 2                                   NaN     3.8           -13.0
# 3  http://www.conceptiontechnology.com/     4.6           -37.0
# 4                    https://fulsy.com/     2.5            -2.0

# %%
Durgapur.columns = ['company_name','company_type','Location','review','no_user_review','contact']

# %%
Haldia.head()
# Out:
#                               company_name  review  no_user_review  \
# 0  South Gate # Haldia Pertochemicals Ltd.     5.0            -2.0
# 1       Petro Carbon & Chemicals Pvt. Ltd.     3.4            -8.0
# 2        RUC Industrial Solutions Pvt Ltd.     3.7            -3.0
# 3                                      HPL     4.4           -22.0
# 4            Haldia Petrochemicals Limited     4.3          -133.0
#
#                     company_type                             location  \
# 0          Chemical Manufacturer               3453+MQX, Unnamed Road
# 1          Chemical Manufacturer  3457+MM7, P.O. Oil Refinery, Dist.:
# 2  Industrial equipment supplier        Durgachak Stadium, 29, Market
# 3                 Chemical plant                             3485+89X
# 4                 Chemical plant                             3487+MQ5
#
#          contact                               website
# 0            NaN                                   NaN
# 1  03224 252 553                                   NaN
# 2  03224 272 058                                   NaN
# 3            NaN                                   NaN
# 4            NaN  http://www.haldiapetrochemicals.com/

# %%
Haldia.columns= ['company_name','company_type','Location','review','no_user_review','contact']

# %%
Hoogly.head()
# Out:
#                         company_name  review no_user_review  \
# 0      Shivshakti Agro India Limited     3.5             -6
# 1                  Rakshit Chemicals     NaN            NaN
# 2                           EKSTAC33     5.0             -2
# 3  The Hooghly Mills Company Limited     3.4            -11
# 4      Hooghly Mills Company Limited     3.0             -1
#
#             company_type                                           location
# 0           Manufacturer                      Dankuni Coal Complex Township
# 1  Chemical Manufacturer  V998+3C8, Kalupukur Main Road, Near Chandannag...
# 2         Music producer          304, Ghutia Bazar, Shibtala Road, Hooghly
# 3              Jute Mill          Shop No. 9, Gate No. 1, Garden Reach Road
# 4       Corporate office                           3rd Floor, 10, Clive Row

# %%
Hoogly.columns= ['company_name','company_type','Location','review','no_user_review','contact']

# %%
kharagpur.head()
# Out:
#                                         company_name  \
# 0                            Nazis Groups of company
# 1                                        HCM_Service
# 2                                     GLACIER PHARMA
# 3                                         SSGS Group
# 4  Sagar Business private limited. Fabrication Plant
#
#                                   company_type  \
# 0                             Corporate office
# 1                    Computer Hardware Company
# 2                       Pharmaceutical company
# 3  Real Estate Builders & Construction Company
# 4                             Steel fabricator
#
#                                             location  review no_user_review  \
# 0                                   984P+HRF, O T Rd     NaN            NaN
# 1                           no. 557, Holding, 324/18     NaN            NaN
# 2                                  Municipality road     3.4             -5
# 3  INDA, Kamala Cabin Civil Defense (Suchana 1, K...     4.3            -17
# 4                         Park, Plot-A8, New Town Rd     NaN            NaN
#
#          contact
# 0            NaN
# 1            NaN
# 2   097359 04440
# 3  03222 355 255
# 4   073810 57375

# %%
kharagpur.columns=['company_name','company_type','Location','review','no_user_review','contact']

# %%
Ranigang.head()
# Out:
#                           company_name      company_type  \
# 0             GEOYN SERVICES PVT. LTD.  Software company
# 1    Maheshwari Mining Private Limited    Mining company
# 2  Abhishek trading co palm oil godown      Manufacturer
# 3                  Maheshwari workshop  Home goods store
# 4                          West Bengal        Dairy farm
#
#                                             location        contact  review  \
# 0  2nd Floor, Eye hospital More, Tantia complex, ...   081018 80886     NaN
# 1                                       21, CLM Lane  0341 244 5446     4.4
# 2                                Bengal shristi, NH2            NaN     5.0
# 3                                      J4Q8+HJP, NH2            NaN     4.0
# 4                 3 no, nimcha colleyri, Devi asthan            NaN     NaN
#
#    no_user_review open_close
# 0             NaN        NaN
# 1           -89.0        NaN
# 2            -6.0        NaN
# 3            -4.0        NaN
# 4             NaN        NaN

# %%
Ranigang.columns=['company_name','company_type','Location','review','no_user_review','contact']

# %%
final_df = pd.concat([kolkata,
Bidhannagar,
Sealdah,
Sector5,
Howrah,
Siliguri,
Asansol,
Darjeeling,
Durgapur,
Haldia,
Hoogly,
kharagpur,
Ranigang,], axis=0)

# %%
final_df
# Out:
#                                            qBF1Pd            W4Efsd  \
# 0                                   Mnc Companies                 ·
# 1                                     Buildfusion                 ·
# 2   Unisys Softwares & Holding Industries Limited  Software company
# 3                          Mnc Software Companies                 ·
# 4             Brabender Technologie GmbH & Co. KG      Manufacturer
# ..                                            ...               ...
# 3                                             NaN               NaN
# 4                                             NaN               NaN
# 5                                             NaN               NaN
# 6                                             NaN               NaN
# 7                                             NaN               NaN
#
#                                             W4Efsd 2  MW4etd UY7F9  \
# 0                             2, Dr M.L.K. Sarani Rd     NaN   NaN
# 1                        CG - 79, Salt Lake City, 79     4.7   -10
# 2                                                  ·     NaN   NaN
# 3   1, 8, Major Arterial Road (South East Extension)     NaN   NaN
# 4                                                  ·     NaN   NaN
# ..                                               ...     ...   ...
# 3                                                NaN     NaN   NaN
# 4                                                NaN     NaN   NaN
# 5                                                NaN     NaN   NaN
# 6                                                NaN     NaN   NaN
# 7                                                NaN     NaN   NaN
#
#             UsdlK eXlrNe W4Efsd 3 lcr4fd href  \
# 0             NaN    NaN      NaN         NaN
# 1   033 2358 0960    NaN      NaN         NaN
# 2   033 2229 5359    NaN      NaN         NaN
# 3             NaN    NaN      NaN         NaN
# 4             NaN    NaN      NaN         NaN
# ..            ...    ...      ...         ...
# 3             NaN    NaN      NaN         NaN
# 4             NaN    NaN      NaN         NaN
# 5             NaN    NaN      NaN         NaN
# 6             NaN    NaN      NaN         NaN
# 7             NaN    NaN      NaN         NaN
#
#                           company_name  review no_user_review  \
# 0                                  NaN     NaN            NaN
# 1                                  NaN     NaN            NaN
# 2                                  NaN     NaN            NaN
# 3                                  NaN     NaN            NaN
# 4                                  NaN     NaN            NaN
# ..                                 ...     ...            ...
# 3                  Maheshwari workshop     4.0           -4.0
# 4                          West Bengal     NaN            NaN
# 5   Mining and Engineering Corporation     NaN            NaN
# 6                  MAKTECH CORPORATION     NaN            NaN
# 7                    SPL LITTI AND TEA     5.0           -1.0
#
#          company_type                            location       contact  \
# 0                 NaN                                 NaN           NaN
# 1                 NaN                                 NaN           NaN
# 2                 NaN                                 NaN           NaN
# 3                 NaN                                 NaN           NaN
# 4                 NaN                                 NaN           NaN
# ..                ...                                 ...           ...
# 3    Home goods store                       J4Q8+HJP, NH2           NaN
# 4          Dairy farm  3 no, nimcha colleyri, Devi asthan           NaN
# 5      Tractor dealer                          Kunustoria           NaN
# 6          Contractor                 46, College Para Rd  075950 25279
# 7   Food manufacturer                            J4JG+HX8           NaN
#
#    website          open_close
# 0      NaN                 NaN
# 1      NaN                 NaN
# 2      NaN                 NaN
# 3      NaN                 NaN
# 4      NaN                 NaN
# ..     ...                 ...
# 3      NaN                 NaN
# 4      NaN                 NaN
# 5      NaN  Temporarily closed
# 6      NaN  Temporarily closed
# 7      NaN  Temporarily closed
#
# [514 rows x 17 columns]
